# %%
pip install pyautogui
# Out:
# ...
#      ---------------------------------------- 0.0/61.2 kB ? eta -:--:--
#      --------------------------------- ------ 51.2/61.2 kB ? eta -:--:--
#      ---------------------------------------- 61.2/61.2 kB 1.1 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#   Installing build dependencies: started
#   Installing build dependencies: still running...
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...

# %%
import cv2
import mediapipe
import pyautogui

# %%
capture_hands=mediapipe.solutions.hands.Hands()
drawing_option=mediapipe.solutions.drawing_utils
# Setting up the screen width and height to use forefinger and thumb as a mouse
screen_width,screen_height=pyautogui.size()
cap=cv2.VideoCapture(0)
x1=y1=x2=y2=0
while cap.isOpened():
    ret, frame=cap.read()
    image_height,image_width,ret= image.shape# Setting image width and height(to identify the points)
    image=cv2.flip(frame,1)                        # (1 is vertical axis and can be flipped to y-axis)
    rgb_image=cv2.cvtColor(image,cv2.COLOR_BGR2RGB)#(converting into rgb color)
    image_height,image_width,ret= image.shape
    out_hands=capture_hands.process(rgb_image)     #(capturing all hands)
    all_hands=out_hands.multi_hand_landmarks
    if all_hands:
        for hand in all_hands:
            drawing_option.draw_landmarks(image,hand)
            one_hand_landmarks=hand.landmark # capturing the landmarks of one hand
            # Now from one hand landmarks we are going to capture two fingers(thumb and forefinger)
            # Then marking points on the fingers
            # Capturing all the ids of points using enumerate function
            for id, lm in enumerate(one_hand_landmarks):
                # These values x and y are in floating numbers
                # To make it in integers we will use int
                x=int(lm.x*image_width)
                y=int(lm.y*image_height)
                # print(x,y)
                if id==8: #(id for forefinger)
                    # We need to create a Mouse to move all over the screen width and height
                    mouse_x=int(screen_width/image_width*x)
                    mouse_y=int(screen_height/image_height*y)
                    cv2.circle(image,(x,y),10,(0,255,255)) #(radius=10(for forefinger),color=yellow(0,255,255))
                    pyautogui.moveTo(mouse_x,mouse_y)
                    x1=x
                    y1=y
                if id==4: #(id for thumb)
                    x2=x
                    y2=y
                    cv2.circle(image,(x,y),10,(0,255,255)) #(radius=10(for thumb),color=yellow(0,255,255))
        dist=y2-y1
        print(dist)
        if(dist<20):
            pyautogui.click()
                    
    cv2.imshow("Hand movement video capture",image)
    if cv2.waitKey(10)==ord('q'):
        break
        
cap.release()
cv2.destroyAllWindows()
# Out:
# -112
# -99
# -95
# -96
# -96
# -98
# -98
# -98
# -95
# -102
# -93
# -97
# -100
# -95
# -98
# -103
# -100
# -93
# -93
# -97
# -105
# -99
# -88
# -97
# -95
# -99
# -93
# -94
# -100
# -70
# 4
# -38
# -9
# 231
# 257
# 250
# 251
# 250
# 254
# 254
# 247
# 250
# 194
# 182
# 196
# 201
# 148
# 104
# 159
# 218
# 217
# 219
# 116
# 266
# 293
# 302
# 307
# 310
# 308
# 308
# 313
# 305
# 311
# 312
# 304
# 298
# 308
# 352
# 304
# 297
# 284
# 284
# 262
# 243
# 210
# 186
# 176
# 161
# 150
# 115
# 110
# 107
# 98
# 101
# 72
# 66
# 74
# 62
# 57
# 50
# 58
# 55
# 53
# 46
# 53
# 60
# 49
# 21
# 41
# 25
# 20
# 61
# 47
# 45
# 63
# 24
# 36
# 42
# 42
# 46
# 41
# 26
# 44
# 45
# 37
# 48
# 38
# 16
# 17
# 39
# 22
# 34
# 18
# 18
